# %%
import pandas as pd

# %%
df = pd.read_csv("data/SAFI_openrefine.csv")
df
# Out:
#     interview_date  quest_no                     start  \
# 0        17-Nov-16         1  2017-03-23T09:49:57.000Z
# 1        17-Nov-16         1  2017-04-02T09:48:16.000Z
# 2        17-Nov-16         3  2017-04-02T14:35:26.000Z
# 3        17-Nov-16         4  2017-04-02T14:55:18.000Z
# 4        17-Nov-16         5  2017-04-02T15:10:35.000Z
# ..             ...       ...                       ...
# 126      18-May-17       126  2017-05-18T04:13:37.000Z
# 127       4-Jun-17       193  2017-06-04T09:36:20.000Z
# 128       4-Jun-17       194  2017-06-04T10:13:36.000Z
# 129       4-Jun-17       199  2017-06-04T10:33:55.000Z
# 130       4-Jun-17       200  2017-06-04T10:52:46.000Z
#
#                           end province district     ward   village  \
# 0    2017-04-02T17:29:08.000Z   Manica   Manica  Bandula       God
# 1    2017-04-02T17:26:19.000Z   Manica   Manica  Bandula       God
# 2    2017-04-02T17:26:53.000Z   Manica   Manica  Bandula       God
# ...

# %%
df.isnull()
# Out:
#      interview_date  quest_no  start    end  province  district   ward  \
# 0             False     False  False  False     False     False  False
# 1             False     False  False  False     False     False  False
# 2             False     False  False  False     False     False  False
# 3             False     False  False  False     False     False  False
# 4             False     False  False  False     False     False  False
# ..              ...       ...    ...    ...       ...       ...    ...
# 126           False     False  False  False     False     False  False
# 127           False     False  False  False     False     False  False
# 128           False     False  False  False     False     False  False
# 129           False     False  False  False     False     False  False
# 130           False     False  False  False     False     False  False
#
#      village  years_farm  agr_assoc  ...  items_owned  items_owned_other  \
# ...

# %%
df = df.drop(columns=["items_owned_other"])
df
# Out:
#     interview_date  quest_no                     start  \
# 0        17-Nov-16         1  2017-03-23T09:49:57.000Z
# 1        17-Nov-16         1  2017-04-02T09:48:16.000Z
# 2        17-Nov-16         3  2017-04-02T14:35:26.000Z
# 3        17-Nov-16         4  2017-04-02T14:55:18.000Z
# 4        17-Nov-16         5  2017-04-02T15:10:35.000Z
# ..             ...       ...                       ...
# 126      18-May-17       126  2017-05-18T04:13:37.000Z
# 127       4-Jun-17       193  2017-06-04T09:36:20.000Z
# 128       4-Jun-17       194  2017-06-04T10:13:36.000Z
# 129       4-Jun-17       199  2017-06-04T10:33:55.000Z
# 130       4-Jun-17       200  2017-06-04T10:52:46.000Z
#
#                           end province district     ward   village  \
# 0    2017-04-02T17:29:08.000Z   Manica   Manica  Bandula       God
# 1    2017-04-02T17:26:19.000Z   Manica   Manica  Bandula       God
# 2    2017-04-02T17:26:53.000Z   Manica   Manica  Bandula       God
# ...

# %%
df.drop(columns=["no_food_mitigation", "gps_Altitude"])
# Out:
#     interview_date  quest_no                     start  \
# 0        17-Nov-16         1  2017-03-23T09:49:57.000Z
# 1        17-Nov-16         1  2017-04-02T09:48:16.000Z
# 2        17-Nov-16         3  2017-04-02T14:35:26.000Z
# 3        17-Nov-16         4  2017-04-02T14:55:18.000Z
# 4        17-Nov-16         5  2017-04-02T15:10:35.000Z
# ..             ...       ...                       ...
# 126      18-May-17       126  2017-05-18T04:13:37.000Z
# 127       4-Jun-17       193  2017-06-04T09:36:20.000Z
# 128       4-Jun-17       194  2017-06-04T10:13:36.000Z
# 129       4-Jun-17       199  2017-06-04T10:33:55.000Z
# 130       4-Jun-17       200  2017-06-04T10:52:46.000Z
#
#                           end province district     ward   village  \
# 0    2017-04-02T17:29:08.000Z   Manica   Manica  Bandula       God
# 1    2017-04-02T17:26:19.000Z   Manica   Manica  Bandula       God
# 2    2017-04-02T17:26:53.000Z   Manica   Manica  Bandula       God
# ...

# %%
df2 = pd.read_csv("data/SAFI_clean.csv")
df2
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# ..      ...       ...                   ...        ...        ...
# 126     126     Ruaca  2017-05-18T00:00:00Z          3          7
# 127     193     Ruaca  2017-06-04T00:00:00Z          7         10
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
# 130     200  Chirodzo  2017-06-04T00:00:00Z          8         20
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0                muddaub      1        NaN              NaN          1
# ...

# %%
df2.isnull()
# Out:
#      key_ID  village  interview_date  no_membrs  years_liv  \
# 0     False    False           False      False      False
# 1     False    False           False      False      False
# 2     False    False           False      False      False
# 3     False    False           False      False      False
# 4     False    False           False      False      False
# ..      ...      ...             ...        ...        ...
# 126   False    False           False      False      False
# 127   False    False           False      False      False
# 128   False    False           False      False      False
# 129   False    False           False      False      False
# 130   False    False           False      False      False
#
#      respondent_wall_type  rooms  memb_assoc  affect_conflicts  liv_count  \
# 0                   False  False        True              True      False
# 1                   False  False       False             False      False
# ...

# %%
df2.dropna()
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# ..      ...       ...                   ...        ...        ...
# 125     192  Chirodzo  2017-06-03T00:00:00Z          9         20
# 126     126     Ruaca  2017-05-18T00:00:00Z          3          7
# 127     193     Ruaca  2017-06-04T00:00:00Z          7         10
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 1                muddaub      1        yes             once          3
# ...

# %%
def oldest_farm(x):
    x = df["years_farm"].max()
    output = "The oldest farm is " + str(x)
    return output
df3 = df["years_farm"].apply(oldest_farm)
print(df3)
# Out:
# 0      The oldest farm is 60
# 1      The oldest farm is 60
# 2      The oldest farm is 60
# 3      The oldest farm is 60
# 4      The oldest farm is 60
#                ...
# 126    The oldest farm is 60
# 127    The oldest farm is 60
# 128    The oldest farm is 60
# 129    The oldest farm is 60
# 130    The oldest farm is 60
# Name: years_farm, Length: 131, dtype: object
