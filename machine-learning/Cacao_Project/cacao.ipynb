# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/flavors_of_cacao.csv")

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.jointplot(y=df["Rating"], x=df["Cocoa Percent"])

# %%
sns.barplot(x=df["Company (Maker-if known)"], y=df["Rating"])
# Out:
# <Axes: xlabel='Company\xa0(Maker-if known)', ylabel='Rating'>

# %%
sns.scatterplot(y=df["Rating"], x=df["Review Date"])
# Out:
# <Axes: xlabel='Review Date', ylabel='Rating'>

# %%
sns.scatterplot(x=df["Company Location"], y=df["Rating"])
# Out:
# <Axes: xlabel='Company Location', ylabel='Rating'>

# %%
sns.scatterplot(x=df["Bean Type"], y=df["Rating"])
# Out:
# <Axes: xlabel='Bean Type', ylabel='Rating'>

# %%
sns.scatterplot(x=df["Company (Maker-if known)"], y=df["Cocoa Percent"])
# Out:
# <Axes: xlabel='Company\xa0(Maker-if known)', ylabel='Cocoa Percent'>

# %%
sns.countplot(y=df["Company Location"], order=df["Company Location"].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Company Location'>

# %%
sns.countplot(y=df["Company (Maker-if known)"], order=df["Company (Maker-if known)"].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Company\xa0(Maker-if known)'>

# %%
sns.countplot(y=df["Broad Bean Origin"], order=df["Broad Bean Origin"].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Broad Bean Origin'>

# %%
sns.countplot(y=df["Rating"], order=df["Rating"].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Rating'>

# %%
sns.scatterplot(x=df["Broad Bean Origin"], y=df["Cocoa Percent"])
# Out:
# <Axes: xlabel='Broad Bean Origin', ylabel='Cocoa Percent'>

# %%
sns.scatterplot(x=df["Review Date"], y=df["Cocoa Percent"])
# Out:
# <Axes: xlabel='Review Date', ylabel='Cocoa Percent'>

# %%
high_rating = df.sort_values(by="Rating", ascending=False)
top5 = high_rating.head()
print(top5)
# Out:
#      Company (Maker-if known) Specific Bean Originor Bar Name   REF  \
# 78                     Amedei                           Chuao   111
# 86                     Amedei                   Toscano Black    40
# 222                    Bonnat                           Kaori  1339
# 76                     Amedei                       Porcelana   111
# 1663   Tobago Estate (Pralus)              Roxborough, Tobago   895
#
#       Review Date Cocoa Percent Company Location  Rating            Bean Type  \
# 78           2007           70%            Italy     5.0           Trinitario
# 86           2006           70%            Italy     5.0                Blend
# 222          2014           75%           France     4.0
# 76           2007           70%            Italy     4.0  Criollo (Porcelana)
# 1663         2012           70%           France     4.0           Trinitario
#
#      Broad Bean Origin
# 78           Venezuela
# 86
# 222             Brazil
# 76           Venezuela
# ...

# %%
high_percent = df.sort_values(by="Cocoa Percent", ascending=False)
percent_top5 = high_percent.head()
print(percent_top5)
# Out:
#      Company (Maker-if known)      Specific Bean Originor Bar Name  REF  \
# 1120           Michel Cluizel                          Noir Infini   81
# 1623                     TCHO                        Peru- Ecuador  915
# 759                  Guittard                             Nocturne  387
# 1658                     Theo  Venezuela; Barinos, Merida, Tachron  188
# 324   Cacaoyere (Ecuatoriana)                            Pichincha  259
#
#       Review Date Cocoa Percent Company Location  Rating           Bean Type  \
# 1120         2006           99%           France    2.00
# 1623         2012           99%           U.S.A.    3.25
# 759          2009           91%           U.S.A.    3.00
# 1658         2007           91%           U.S.A.    2.00               Blend
# 324          2008           91%          Ecuador    1.50  Forastero (Arriba)
#
#      Broad Bean Origin
# 1120
# 1623     Peru, Ecuador
# 759
# 1658         Venezuela
# 324            Ecuador

# %%
low_rating = df.sort_values(by="Rating", ascending=True)
bottom5 = low_rating.head()
print(bottom5)
# Out:
#      Company (Maker-if known) Specific Bean Originor Bar Name  REF  \
# 326                 Callebaut                          Baking  141
# 437           Claudio Corallo                        Principe  252
# 465        Cote d' Or (Kraft)              Sensations Intense   48
# 1175      Neuhaus (Callebaut)                            Dark  135
# 554        Dolfin (Belcolade)                            Noir   63
#
#       Review Date Cocoa Percent Company Location  Rating  Bean Type  \
# 326          2007           70%          Belgium     1.0
# 437          2008          100%         Sao Tome     1.0  Forastero
# 465          2006           70%          Belgium     1.0
# 1175         2007           73%          Belgium     1.0
# 554          2006           70%          Belgium     1.5
#
#         Broad Bean Origin
# 326               Ecuador
# 437   Sao Tome & Principe
# 465
# 1175
# 554

# %%
low_percent = df.sort_values(by="Cocoa Percent", ascending=True)
percent_bottom5 = low_percent.head()
print(percent_bottom5)
# Out:
#      Company (Maker-if known) Specific Bean Originor Bar Name   REF  \
# 245                    Bonnat                     One Hundred    81
# 1204                     Ocho                   Sang Yum Coop  1760
# 1319                   Pralus       Sambirano Valley, Le 100%   202
# 1411                 S.A.I.D.                     100 percent   615
# 1466                   Sirene          Somia Plantation, 2012  1502
#
#       Review Date Cocoa Percent Company Location  Rating   Bean Type  \
# 245          2006          100%           France    1.50
# 1204         2016          100%      New Zealand    2.75
# 1319         2008          100%           France    3.00     Criollo
# 1411         2010          100%            Italy    1.50
# 1466         2015          100%           Canada    3.00  Trinitario
#
#      Broad Bean Origin
# 245
# 1204             Samoa
# 1319        Madagascar
# 1411
# 1466        Madagascar

# %%
company_counts = df["Company (Maker-if known)"].value_counts()
common_company = company_counts.sort_values(ascending=False).index[0]
print(common_company)
# Out:
# Soma
