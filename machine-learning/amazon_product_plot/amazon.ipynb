# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("data/amz_uk_price_prediction_dataset.csv")

# %%
sns.countplot(x=df["category"])
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
highest_count = df.sort_values("category", ascending=False)
print(highest_count.head())
# Out:
#              uid        asin  \
# 681892    734618  B09BSQ8PRD
# 2325301  2680811  B0BGS7D7BM
# 2325299  2680809  B0CJP6CF8Z
# 2325298  2680808  B0BFBQMH3J
# 2325297  2680807  B0CGMRB52P
#
#                                                      title  stars  reviews  \
# 681892   Kindle Scribe (64 GB), the first Kindle and di...    4.2      548
# 2325301  Foluu Case for All-new Kindle (2022 release) 1...    4.0       24
# 2325299  UKCOCO e-reader protective case e-reader prote...    0.0        0
# 2325298  Amazon Kindle Paperwhite Leather Cover | Compa...    4.6     3135
# 2325297  Mikikit 6 pcs case ereaders e readers E- reade...    0.0        0
#
#           price  isBestSeller  boughtInLastMonth                     category
# 681892   329.99         False                  0  eBook Readers & Accessories
# 2325301   14.99         False                  0  eBook Readers & Accessories
# 2325299   17.59         False                  0  eBook Readers & Accessories
# ...

# %%
sns.scatterplot(x=df["reviews"], y=df["boughtInLastMonth"])
# Out:
# <Axes: xlabel='reviews', ylabel='boughtInLastMonth'>

# %%
sns.scatterplot(x=df["stars"], y=df["boughtInLastMonth"])
# Out:
# <Axes: xlabel='stars', ylabel='boughtInLastMonth'>

# %%
sns.pairplot(data=df)

# %%
sns.barplot(x=df["category"], y=df["stars"])
# Out:
# <Axes: xlabel='category', ylabel='stars'>

# %%
sns.
