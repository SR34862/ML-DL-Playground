# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a = pd.read_csv("data/hearing_test.csv")

# %%
sns.displot(a)

# %%
sns.barplot(a)
# Out:
# <Axes: >

# %%
a = pd.read_csv("Advertising.csv")
sns.pairplot(a)

# %%
sns.scatterplot(a)
# Out:
# <Axes: >

# %%
sns.swarmplot(a)
# Out:
# c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 32.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 65.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: >
# ...

# %%
sns.jointplot(a)
