# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a = pd.read_csv("data/auto-mpg - auto-mpg.csv")

# %%
sns.jointplot(a)

# %%
a.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
col = a[["horsepower","acceleration"]]

# %%
sns.jointplot(col)

# %%
col
# Out:
#     horsepower  acceleration
# 0          130          12.0
# 1          165          11.5
# 2          150          11.0
# 3          150          12.0
# 4          140          10.5
# ..         ...           ...
# 393         86          15.6
# 394         52          24.6
# 395         84          11.6
# 396         79          18.6
# 397         82          19.4
#
# [398 rows x 2 columns]

# %%
b = a

# %%
b
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
b = b.drop("cylinders", axis=1)
b = b.drop("displacement", axis=1)
b = b.drop("horsepower", axis=1)
b = b.drop("model year", axis=1)
b = b.drop("origin", axis=1)
b = b.drop("car name", axis=1)
b = b.drop("weight", axis=1)

# %%
sns.jointplot(b)

# %%
sns.kdeplot(b)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.jointplot(x=b["acceleration"],y=b["mpg"], kind="hex")

# %%
c = a

# %%
c = c.drop("cylinders", axis=1)
c = c.drop("displacement", axis=1)
c = c.drop("horsepower", axis=1)
c = c.drop("model year", axis=1)
c = c.drop("origin", axis=1)
c = c.drop("car name", axis=1)
c = c.drop("acceleration", axis=1)

# %%
sns.jointplot(c)

# %%
sns.kdeplot(c)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.jointplot(x=c["weight"], y=c["mpg"], kind="hex")

# %%
d = a

# %%
d = d.drop("cylinders", axis=1)
d = d.drop("displacement", axis=1)
d = d.drop("horsepower", axis=1)
d = d.drop("model year", axis=1)
d = d.drop("origin", axis=1)
d = d.drop("car name", axis=1)
d = d.drop("mpg", axis=1)

# %%
sns.kdeplot(d)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.jointplot(x=d["weight"], y=d["acceleration"], kind="hex")
